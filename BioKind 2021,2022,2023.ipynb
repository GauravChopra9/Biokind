# %%
# cnvert to data frame pandas
import pandas as pd
df = pd.read_csv("2021 NBC 15 Community Diaper Driver.csv")
df
#group by account type and companies
#math plot.lib for how many company and aindiviaduals where their
# also
# Out:
#       Donation ID  Account ID  Shopping Cart ID  Campaign ID  Donation Amount  \
# 0            1654        1547              1687            6            12.67
# 1            1705        1598              1738            6            26.06
# 2             639         537               672            6            51.80
# 3            1691        1584              1724            6            26.06
# 4            1509        1402              1542            6            51.80
# ...           ...         ...               ...          ...              ...
# 1981          628         526               661            6           103.30
# 1982         1732        1625              1765            6            25.00
# 1983         2203        2096              2236            6            51.80
# 1984         2585        2478              2618            6            26.06
# 1985         1566        1459              1599            6            26.06
#
# ...

# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '.virtual_documents',
#  '2021 NBC 15 Community Diaper Driver.csv',
#  'BioKind 2021,2022,2023.ipynb']

# %%
df=df.loc[:,"Donation ID":"Tender Type"]
df
# Out:
#       Donation ID  Account ID  Shopping Cart ID  Campaign ID  Donation Amount  \
# 0            1654        1547              1687            6            12.67
# 1            1705        1598              1738            6            26.06
# 2             639         537               672            6            51.80
# 3            1691        1584              1724            6            26.06
# 4            1509        1402              1542            6            51.80
# ...           ...         ...               ...          ...              ...
# 1981          628         526               661            6           103.30
# 1982         1732        1625              1765            6            25.00
# 1983         2203        2096              2236            6            51.80
# 1984         2585        2478              2618            6            26.06
# 1985         1566        1459              1599            6            26.06
#
# ...

# %%
df["Account Type"].value_counts()
# Out:
# Account Type
# Individual    1979
# Company          7
# Name: count, dtype: int64

# %%
b = df["Account Type"]=="Individual"

# %%
df[b]
# Out:
#       Donation ID  Account ID  Shopping Cart ID  Campaign ID  Donation Amount  \
# 0            1654        1547              1687            6            12.67
# 1            1705        1598              1738            6            26.06
# 2             639         537               672            6            51.80
# 3            1691        1584              1724            6            26.06
# 4            1509        1402              1542            6            51.80
# ...           ...         ...               ...          ...              ...
# 1981          628         526               661            6           103.30
# 1982         1732        1625              1765            6            25.00
# 1983         2203        2096              2236            6            51.80
# 1984         2585        2478              2618            6            26.06
# 1985         1566        1459              1599            6            26.06
#
# ...

# %%
b = df["Account Type"]=="Company"
df[b]
# Out:
#       Donation ID  Account ID  Shopping Cart ID  Campaign ID  Donation Amount  \
# 300          2638        2512              2671            6            100.0
# 474           545          29               578            6           5000.0
# 810           557         470               590            6            500.0
# 1061         2635        2510              2668            6           2000.0
# 1083          571         476               604            6           5000.0
# 1715         1833        1726              1866            6            500.0
# 1730         2637         266              2670            6           1000.0
#
#      Donation Date Account Type      Full Name (F)  \
# 300     02/25/2021      Company                NaN
# 474     01/04/2021      Company  Michelle Richards
# 810     01/08/2021      Company                NaN
# 1061    02/25/2021      Company       Natalie Lang
# 1083    01/22/2021      Company                NaN
# ...
